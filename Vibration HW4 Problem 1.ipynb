# %%
##inits
import sympy;
import numpy;
import matplotlib.pyplot as plt
import math;
from mpl_toolkits.mplot3d import Axes3D as ax
# %matplotlib inline
from sympy import *
from math import sin, cos, tan, atan

# %%
jnumber = 4.

#constants
m = 1.0;
k = 15000.0;
zeta_ = 0.10;
tau = 0.6;
N = 12.0;
w_n = sqrt(k/m)
w = (2.0*pi)/tau
r = w/w_n;

time = linspace(0,.6,500)

jrange = linspace(1.0,jnumber,jnumber)
#jterms=numpy.zeros((jnumber,24))
#position=linspace(0,0,24)
#a_j = numpy.zeros((12,1))
#b_j = numpy.zeros((12,1))
F = [15., 24., 27., 35., 30., 25., 40. ,6.,-15.,-37.,-28.,0.]
t_s = linspace(0.05, 0.6,12)    # time for sample
a0 = numpy.sum(F)*(2./N)

# %%
# calculate a_j b_j
a = numpy.zeros(len(jrange))
b = numpy.zeros(len(jrange))
for j in jrange:
    for i in range(int(N)):
        a[int(j-1)] += 2/N *F[i] * cos(2*j*pi*t_s[i]/tau) 
        b[int(j-1)] += 2/N *F[i] * sin(2*j*pi*t_s[i]/tau) 
print a
print b
# Out:
# [-20.64668475   4.58333333   4.83333333  -0.91666667]
# [ 22.74038106  12.26869322  -1.5          3.03108891]

# %%
# summation
x_ss = a0/(2*k)*numpy.ones(len(time))
m = 0  # counter
for t in time:
    
    for j in jrange:
        x_ss[m] += a[int(j-1)]/k/sqrt((1.-(j*r)**2)**2+(2.*zeta_*j*r)**2)* cos(j*w*t-math.atan(2.*zeta_*j*r/(1-(j**2)*(r**2))))\
        + b[int(j-1)]/k/(sqrt((1.-(j**2)*(r**2))**2+(2.*zeta_*j*r)**2)) * sin(j*w*t-math.atan(2.*zeta_*j*r/(1-(j**2)*(r**2))))
    m += 1

# %%
plt.figure(figsize=(16,12))
plt.plot(time,x_ss)
plt.grid(True);
plt.title('HW4 Problem 1, Displacement vs. Time for j=4');
plt.ylabel(r'Displacement (X)', fontsize=18);
plt.xlabel(r'Time(t)', fontsize=18);
